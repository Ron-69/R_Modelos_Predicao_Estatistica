# %%
# 01. CARREGAMENTO DE BIBLIOTECAS ESSENCIAIS

# Se os pacotes ainda não estiverem instalados, instale-os:
# install.packages(c("caret", "dplyr", "mlbench", "pROC", "kernlab", "rpart", "randomForest", "gbm"))

# Pacotes Fundamentais
library(caret)
library(dplyr)
library(mlbench)
library(pROC)
library(ggplot2)

# Pacotes Específicos para os Modelos (Carregue APENAS o que for usar no notebook)
library(kernlab)   # Para SVM
# library(klaR)    # Para Naive Bayes
# library(MASS)    # Para LDA
library(rpart)   # Para Árvores de Decisão
# library(randomForest) # Para Random Forest
# library(gbm)     # Para GBM
# Out:
# Carregando pacotes exigidos: ggplot2
#
# Carregando pacotes exigidos: lattice
#
#
# Anexando pacote: 'dplyr'
#
#
# Os seguintes objetos são mascarados por 'package:stats':
#
#     filter, lag
#
#
# Os seguintes objetos são mascarados por 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Type 'citation("pROC")' for a citation.
#
#
# Anexando pacote: 'pROC'
#
#
# Os seguintes objetos são mascarados por 'package:stats':
#
#     cov, smooth, var
#
#
#
# Anexando pacote: 'kernlab'
#
#
# O seguinte objeto é mascarado por 'package:ggplot2':
#
#     alpha

# %%
# 02. Carregar dados
load("data/03_classification_data_splits.RData") 

# Carregar as configurações de controle
control <- readRDS("config/train_control.rds")

# Carregar o modelo RegLog Otimizado para comparação
logreg_otimizado <- readRDS("models/logreg_otimizado.rds")

# Carregar o modelo nb Otimizado para comparação
nb_model <- readRDS("models/nb_model.rds")

# Carregar o modelo lda Otimizado para comparação
lda_model <- readRDS("models/lda_model.rds")

# Carregar o modelo svm Otimizado para comparação
svm_model <- readRDS("models/svm_model.rds")

# Carregar o modelo svm Otimizado para comparação
knn_model <- readRDS("models/knn_model.rds")

# Verificar se carregou
print(dim(train_df))
# Out:
# [1] 538   9

# %%
# --- CÉLULA 6: TREINAMENTO DO MODELO ÁRVORE DE DECISÃO (RPART) ---

message("Treinando Modelo Árvore de Decisão (RPART)...")

# Otimiza o parâmetro 'cp' (Complexidade do Parâmetro)
# cp mais baixo gera árvores maiores e mais complexas.
tree_model <- train(
    diabetes ~ ., 
    data = train_df, 
    method = "rpart",              # Método para Árvores de Decisão
    metric = "ROC", 
    trControl = control, 
    # Padronização (center/scale) não afeta modelos baseados em árvore, mas mantemos
    # a consistência do trControl.
    tuneLength = 20                 # O caret testará 20 valores de cp
)

# Salvar o modelo final (muito útil para a comparação)
saveRDS(tree_model, file = "models/tree_model.rds")

print(tree_model)
# Out:
# Treinando Modelo Árvore de Decisão (RPART)...
# CART
#
# 538 samples
#   8 predictor
#   2 classes: 'Nao_Diabete', 'Diabete'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 3 times)
# Summary of sample sizes: 484, 484, 484, 485, 485, 484, ...
# Resampling results across tuning parameters:
#
#   cp          ROC        Sens       Spec
#   0.00000000  0.7344444  0.7819048  0.5444444
#   0.01623740  0.6936856  0.8142857  0.5192008
#   0.03247480  0.6694277  0.8723810  0.4488304
#   0.04871221  0.6666681  0.8876190  0.4346004
#   0.06494961  0.6564717  0.8466667  0.4662768
#   0.08118701  0.6558452  0.8419048  0.4697856
#   0.09742441  0.6558452  0.8419048  0.4697856
#   0.11366181  0.6558452  0.8419048  0.4697856
#   0.12989922  0.6558452  0.8419048  0.4697856
#   0.14613662  0.6558452  0.8419048  0.4697856
#   0.16237402  0.6558452  0.8419048  0.4697856
#   0.17861142  0.6558452  0.8419048  0.4697856
#   0.19484882  0.6558452  0.8419048  0.4697856
#   0.21108623  0.6558452  0.8419048  0.4697856
#   0.22732363  0.6558452  0.8419048  0.4697856
#   0.24356103  0.6396547  0.8761905  0.4031189
#   0.25979843  0.6286021  0.8961905  0.3610136
#   0.27603583  0.6139655  0.9142857  0.3136452
#   0.29227324  0.5851448  0.9409524  0.2293372
#   0.30851064  0.5493651  0.9542857  0.1444444
#
# ROC was used to select the optimal model using the largest value.
# The final value used for the model was cp = 0.
